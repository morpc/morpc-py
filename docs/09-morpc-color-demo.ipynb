# %% [markdown]
# # morpc.color Demo

# %% [markdown]
# ## Import morpc package

# %%
import morpc

# %% [markdown]
# ## Standard Palettes

# %%
morpc.palette.SEQ.keys()
# Out:
# dict_keys(['darkblue', 'darkblue_r', 'midblue', 'midblue_r', 'blue', 'blue_r', 'bluegreen', 'bluegreen_r', 'darkgreen', 'darkgreen_r', 'lightgreen', 'lightgreen_r', 'darkgrey', 'darkgrey_r', 'lightgrey', 'lightgrey_r', 'yellow', 'yellow_r', 'tan', 'tan_r', 'red', 'red_r', 'purple', 'purple_r'])

# %%
morpc.color.plot_from_hex_list(morpc.palette.SEQ['darkblue_r'], labels=[])

# %%
morpc.palette.SEQ2.keys()
# Out:
# dict_keys(['darkblue-midblue', 'darkblue-blue', 'darkblue-bluegreen', 'darkblue-darkgreen', 'darkblue-lightgreen', 'darkblue-darkgrey', 'darkblue-lightgrey', 'darkblue-yellow', 'darkblue-tan', 'darkblue-red', 'darkblue-purple', 'midblue-darkblue', 'midblue-blue', 'midblue-bluegreen', 'midblue-darkgreen', 'midblue-lightgreen', 'midblue-darkgrey', 'midblue-lightgrey', 'midblue-yellow', 'midblue-tan', 'midblue-red', 'midblue-purple', 'blue-darkblue', 'blue-midblue', 'blue-bluegreen', 'blue-darkgreen', 'blue-lightgreen', 'blue-darkgrey', 'blue-lightgrey', 'blue-yellow', 'blue-tan', 'blue-red', 'blue-purple', 'bluegreen-darkblue', 'bluegreen-midblue', 'bluegreen-blue', 'bluegreen-darkgreen', 'bluegreen-lightgreen', 'bluegreen-darkgrey', 'bluegreen-lightgrey', 'bluegreen-yellow', 'bluegreen-tan', 'bluegreen-red', 'bluegreen-purple', 'darkgreen-darkblue', 'darkgreen-midblue', 'darkgreen-blue', 'darkgreen-bluegreen', 'darkgreen-lightgreen', 'darkgreen-darkgrey', 'darkgreen-lightgrey', 'darkgreen-yellow', 'darkgreen-tan', 'darkgreen-red', 'darkgreen-purple', 'lightgreen-darkblue', 'lightgreen-midblue', 'lightgreen-blue', 'lightgreen-bluegreen', 'lightgreen-darkgreen', 'lightgreen-darkgrey', 'lightgreen-lightgrey', 'lightgreen-yellow', 'lightgreen-tan', 'lightgreen-red', 'lightgreen-purple', 'darkgrey-darkblue', 'darkgrey-midblue', 'darkgrey-blue', 'darkgrey-bluegreen', 'darkgrey-darkgreen', 'darkgrey-lightgreen', 'darkgrey-lightgrey', 'darkgrey-yellow', 'darkgrey-tan', 'darkgrey-red', 'darkgrey-purple', 'lightgrey-darkblue', 'lightgrey-midblue', 'lightgrey-blue', 'lightgrey-bluegreen', 'lightgrey-darkgreen', 'lightgrey-lightgreen', 'lightgrey-darkgrey', 'lightgrey-yellow', 'lightgrey-tan', 'lightgrey-red', 'lightgrey-purple', 'yellow-darkblue', 'yellow-midblue', 'yellow-blue', 'yellow-bluegreen', 'yellow-darkgreen', 'yellow-lightgreen', 'yellow-darkgrey', 'yellow-lightgrey', 'yellow-tan', 'yellow-red', 'yellow-purple', 'tan-darkblue', 'tan-midblue', 'tan-blue', 'tan-bluegreen', 'tan-darkgreen', 'tan-lightgreen', 'tan-darkgrey', 'tan-lightgrey', 'tan-yellow', 'tan-red', 'tan-purple', 'red-darkblue', 'red-midblue', 'red-blue', 'red-bluegreen', 'red-darkgreen', 'red-lightgreen', 'red-darkgrey', 'red-lightgrey', 'red-yellow', 'red-tan', 'red-purple', 'purple-darkblue', 'purple-midblue', 'purple-blue', 'purple-bluegreen', 'purple-darkgreen', 'purple-lightgreen', 'purple-darkgrey', 'purple-lightgrey', 'purple-yellow', 'purple-tan', 'purple-red'])

# %%
morpc.color.plot_from_hex_list(morpc.palette.SEQ2['yellow-darkgreen'])

# %%
morpc.color.get_colors().KEYS
# Out:
# {'darkblue': '#365072',
#  'midblue': '#34617a',
#  'blue': '#0077bf',
#  'bluegreen': '#00b0bc',
#  'darkgreen': '#2a7f67',
#  'lightgreen': '#5ab55f',
#  'darkgrey': '#727a82',
#  'lightgrey': '#aab1b6',
#  'yellow': '#f7a402',
#  'tan': '#bc7e6a',
#  'red': '#eb111c',
#  'purple': '#af47b0'}

# %%
morpc.color.plot_from_hex_list(morpc.palette.QUAL['morpc'])

# %%
morpc.color.plot_from_hex_list(morpc.palette.QUAL['morpc_ext'])

# %%
morpc.color.plot_from_hex_list(morpc.palette.QUAL['light'])

# %%
morpc.color.plot_from_hex_list(morpc.palette.QUAL['dark'])

# %% [markdown]
# ## Get standard HEX color codes

# %% [markdown]
# The get_colors() class provides access to a json file that contains various useful definitions of colors. It takes one argument `colorDictPath='../morpc/color/morpc_colors.json'` which is the relative path to the json file.
#
# The json file is stored in the attribute morpc_colors.

# %%
morpc.color.get_colors().morpc_colors['darkblue']

# %% [markdown]
# ## Key Colors

# %% [markdown]
# The standard colors are retrieved using `.KEYS` instance.

# %%
morpc.color.get_colors().KEYS

# %% [markdown]
# ## Plot color strips from hex lists to see colors

# %% [markdown]
# You can plot a list of hex codes using the `plot_from_hex_list()` function. In the following example, we pass the values of the key colors to see them. The plot includes the HLS values, a grey values, and the hex code.

# %%
morpc.color.plot_from_hex_list(morpc.color.get_colors().KEYS.values(), labels=['hex'])

# %% [markdown]
# ## Sequential color gradients for each color

# %% [markdown]
# Each color has an associated gradient. These gradients can be returned using the `.SEQ()` function. Simply pass the color name to the funcion.

# %%
morpc.color.get_colors().SEQ('midblue')

# %%
morpc.color.plot_from_hex_list(morpc.color.get_colors().SEQ('midblue'))

# %%
for color in morpc.color.get_colors().morpc_colors:
    key = morpc.color.get_colors().morpc_colors[color]['key']['position']
    morpc.color.plot_from_hex_list(morpc.color.get_colors().SEQ(color), position = key, labels=['hex'])

# %% [markdown]
# ## Two color sequential gradients

# %% [markdown]
# Pass a list of two color names to `.SEQ2()` method to get a split gradient.

# %%
import morpc

# %%
morpc.color.plot_from_hex_list(morpc.color.get_colors().SEQ2(['yellow', 'darkgreen']), labels=[])

# %%
morpc.color.plot_from_hex_list(morpc.color.get_colors().SEQ2(['red', 'purple']), labels=[])

# %% [markdown]
# ## Three color sequential gradients

# %% [markdown]
# The same can be done with three colors using `.SEQ3()` method.

# %%
morpc.color.plot_from_hex_list(morpc.color.get_colors().SEQ3(['yellow', 'lightgreen', 'darkblue']), labels=[])

# %%
morpc.color.plot_from_hex_list(morpc.color.get_colors().SEQ3(['yellow', 'red', 'purple']), labels=[])

# %%
morpc.color.plot_from_hex_list(morpc.color.get_colors().SEQ3(['purple', 'bluegreen', 'darkblue']), labels=[])

# %%
morpc.color.plot_from_hex_list(morpc.color.get_colors().SEQ3(['lightgrey', 'lightgreen', 'darkgreen']), labels=[])

# %% [markdown]
# ## Diverging color gradients

# %% [markdown]
# Use the `.DIV()` method can be used to create diverging gradients and color maps.

# %%
morpc.color.plot_from_hex_list(morpc.color.get_colors().DIV(['darkgreen', 'lightgrey','darkblue']), labels=[])

# %%
morpc.color.plot_from_hex_list(morpc.color.get_colors().DIV(['red','yellow','lightgreen']), labels=[])

# %% [markdown]
# ## Qualitative color groups

# %% [markdown]
# Use the `.QUAL()` method to return groups for qualitative data. It selects a number of grouped lightness variations of each color.

# %%
import morpc

# %%
morpc.color.get_colors().morpc_colors

# %%
morpc.color.get_colors().KEYS

# %%
morpc.color.plot_from_hex_list(morpc.color.get_colors().QUAL(6).hex_list, labels=[])

# %% [markdown]
# ## Testing color maps for color blindness accessibility

# %%
morpc.color.get_continuous_cmap(morpc.color.get_colors().DIV(['red', 'yellow', 'darkgreen']))

# %%
import numpy as np
import matplotlib.pyplot as plt
cmap = morpc.color.get_continuous_cmap(morpc.color.get_colors().DIV(['red', 'yellow', 'darkgreen']))
np.random.seed(19680801)
data = np.random.randn(30, 30)
fig, ax = plt.subplots()
psm = ax.pcolormesh(data, cmap=cmap, rasterized=True, vmin=-4, vmax=4)
fig.colorbar(psm, ax=ax)

# %%
from daltonize import daltonize
daltonize.simulate_mpl(fig, color_deficit='d')

# %% [markdown]
# # Update to MORP Color Palette

# %%
import morpc

# %% [markdown]
# ## Purple

# %%
hue = 0.832
sats =  [0.08, 0.14, 0.18, 0.26, 0.33, 0.42, 0.48, 0.44, 0.37, 0.3, 0.24]
greys = [0.95, 0.87, 0.78, 0.67, 0.56, 0.45, 0.33, 0.26, 0.20, 0.15, 0.08]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)

# %%
morpc.color.plot_from_rgb_list(rgb_scale, position=6, labels=['hex'])

# %%
purple = {"purple": {
    "key": {
        "position": 6,
        "pantone": "7442 C"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Red

# %%
hue = .992
sats =  [0.5,  0.54, 0.58, 0.64, 0.74,  0.80, 0.86, 0.89, 0.82, 0.76, 0.70]
greys = [0.95, 0.87, 0.78, 0.67, 0.56, 0.45, 0.33, 0.26, 0.20, 0.15, 0.08]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, position=7, labels=['hex'])

# %%
red = {"red": {
    "key": {
        "position": 7,
        "pantone": "185 C"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Tan

# %%
hue = .04
sats =  [0.22,  0.26, 0.29, 0.35, 0.38,  0.43, 0.48, 0.50, 0.46, 0.42, 0.40]
greys = [0.95, 0.87, 0.78, 0.67, 0.56, 0.45, 0.33, 0.26, 0.20, 0.15, 0.08]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, position=5, labels=['hex'])

# %%
tan = {"tan": {
    "key": {
        "position": 5,
        "pantone": "7515 C"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Yellow

# %%
hue = .110
sats =  [0.78, 0.84, 0.90, 0.98, 0.96, 0.93, 0.90, 0.87, 0.84, 0.80, 0.78]
greys = [0.95, 0.87, 0.78, 0.67, 0.58, 0.45, 0.33, 0.26, 0.20, 0.15, 0.08]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, labels=['hex'], position=4)

# %%
yellow = {"yellow": {
    "key": {
        "position": 4,
        "pantone": "137 C"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Light Green

# %%
hue = .342
sats =  [0.12, 0.18, 0.22, 0.36, 0.39, 0.46, 0.58, 0.58, 0.44, 0.36, 0.28]
greys = [0.95, 0.87, 0.78, 0.66, 0.57, 0.45, 0.33, 0.26, 0.20, 0.15, 0.08]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, position=5, labels=['hex'])

# %%
lightgreen = {"lightgreen": {
    "key": {
        "position": 5,
        "pantone": "360 C"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Dark Blue

# %%
hue = .594
greys = [0.95, 0.87, 0.78, 0.68, 0.58, 0.45, 0.39, 0.30, 0.21, 0.15, 0.08]
sats =  [0.10, 0.12, 0.15, 0.18, 0.22, 0.29, 0.33, 0.36, 0.44, 0.55, 0.46]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, position=8, labels=['hex'])

# %%
darkblue = {"darkblue": {
    "key": {
        "position": 8,
        "pantone": "295 U"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Mid Blue

# %%
hue = .559
greys = [0.95, 0.87, 0.78, 0.68, 0.58, 0.46, 0.34, 0.28, 0.21, 0.15, 0.08]
sats =  [0.16, 0.18, 0.22, 0.26, 0.30, 0.34, 0.40, 0.37, 0.33, 0.30, 0.25]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, position=7, labels=['hex'])

# %%
midblue = {"midblue": {
    "key": {
        "position": 7,
        "pantone": "3025 U"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Blue

# %%
hue = .5628
greys= [0.95, 0.87, 0.78, 0.68, 0.58, 0.43, 0.36, 0.28, 0.21, 0.15, 0.08]
sats=  [0.50, 0.64, 0.68, 0.74, 0.80, 0.84, 1.00, 1.00, 0.98, 0.92, 0.87]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, position=7, labels=['hex'])

# %%
blue = {"blue": {
    "key": {
        "position": 7,
        "pantone": "3005 U"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Bluegreen

# %%
hue = .511
greys= [0.95, 0.87, 0.78, 0.68, 0.58, 0.49, 0.36, 0.28, 0.21, 0.15, 0.08]
sats=  [0.55, 0.68, 0.75, 0.86, 0.95, 1.00, 0.95, 0.93, 0.89, 0.85, 0.80]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, position=6, labels=['hex'])

# %%
bluegreen = {"bluegreen": {
    "key": {
        "position": 6,
        "pantone": "7466 U"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Dark Green

# %%
hue = .453
greys= [0.95, 0.87, 0.78, 0.68, 0.58, 0.45, 0.39, 0.28, 0.21, 0.15, 0.08]
sats=  [0.16, 0.22, 0.28, 0.32, 0.36, 0.44, 0.50, 0.54, 0.54, 0.50, 0.46]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, position=7, labels=['hex'])

# %%
darkgreen = {"darkgreen": {
    "key": {
        "position": 7,
        "pantone": "3415 U"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Light Green

# %%
hue = .3425
greys= [0.95, 0.87, 0.78, 0.68, 0.567, 0.45, 0.36, 0.28, 0.21, 0.15, 0.08]
sats=  [0.12, 0.18, 0.22, 0.32, 0.383, 0.46, 0.58, 0.58, 0.44, 0.36, 0.28]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, position=5, labels=['hex'])

# %%
lightgreen = {"lightgreen": {
    "key": {
        "position": 5,
        "pantone": "360 U"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Dark grey

# %%
hue = .578
greys= [0.95, 0.87, 0.78, 0.68, 0.57, 0.475, 0.38, 0.28, 0.21, 0.15, 0.08]
sats=  [0.01, 0.03, 0.05, 0.06, 0.06, 0.067, 0.08, 0.08, 0.06, 0.04, 0.02]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, position=6, labels=['hex'])

# %%
darkgrey = {"darkgrey": {
    "key": {
        "position": 6,
        "pantone": "431 U"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Light Grey

# %%
hue = .569
greys= [0.95, 0.87, 0.78, 0.69, 0.57, 0.475, 0.38, 0.28, 0.21, 0.15, 0.08]
sats=  [0.04, 0.06, 0.08, 0.076, 0.09, 0.09, 0.08, 0.08, 0.06, 0.04, 0.02]
rgb_scale = morpc.color.rgb_scale_from_hue(hue, sats, greys)
morpc.color.plot_from_rgb_list(rgb_scale, position=4, labels=['hex'])

# %%
lightgrey = {"lightgrey": {
    "key": {
        "position": 4,
        "pantone": "428 U"
    },
    "hls": {
        "hue": hue,
        "sat": sats,
        "greys": greys
    },
    "gradient": {
        "rgb": rgb_scale,
        "hex": morpc.color.rgb_list_to_hex_list(rgb_scale)
    }
}
}

# %% [markdown]
# ## Build JSON

# %%
darkblue

# %%
dicts = [darkblue, midblue, blue, bluegreen, darkgreen, lightgreen, darkgrey, lightgrey, yellow, tan, red, purple]

# %%
morpc_colors = {}
for d in dicts:
    for k, v in d.items():  # d.items() in Python 3+
        morpc_colors[k] = v

# %%
import json

# %%
# with open('../morpc/color/morpc_colors.json', 'w') as file:
#    json.dump(morpc_colors, file)
