# %%
import morpc

# %%
morpc.get_colors().KEYS
# Out:
# {'darkblue': '#2e5072',
#  'blue': '#0077bf',
#  'darkgreen': '#2c7f68',
#  'lightgreen': '#66b561',
#  'bluegreen': '#00b2bf',
#  'midblue': '#2c6179',
#  'rose': '#b0503f',
#  'gold': '#977118'}

# %%
morpc.color.plot_from_hex_list(morpc.get_colors().KEYS.values())

# %%
morpc.color.plot_from_hex_list(morpc.get_colors().SEQ('darkblue').hex_list)

# %%
morpc.color.plot_from_hex_list(morpc.get_colors().SEQ('gold', 6).hex_list)

# %%
morpc.color.plot_from_hex_list(morpc.get_colors().SEQ2(['gold', 'darkblue']).hex_list)

# %%
morpc.color.plot_from_hex_list(morpc.get_colors().SEQ2(['rose', 'blue']).hex_list)

# %%
morpc.color.plot_from_hex_list(morpc.get_colors().SEQ3(['gold', 'darkgreen', 'darkblue']).hex_list)

# %%
morpc.get_colors().SEQ3(['rose', 'darkgreen', 'darkblue']).cmap

# %%
morpc.color.plot_from_hex_list(morpc.get_colors().DIV(['rose','darkgreen']).hex_list)

# %%
morpc.color.plot_from_hex_list(morpc.get_colors().QUAL(20).hex_list)

# %%
morpc.get_colors().DIV(['darkblue', 'gold']).cmap

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(19680801)
data = np.random.randn(30, 30)
fig, ax = plt.subplots()
psm = ax.pcolormesh(data, cmap=morpc.get_colors().DIV(['blue', 'lightgreen']).cmap, rasterized=True, vmin=-4, vmax=4)
fig.colorbar(psm, ax=ax)

# %%
from daltonize import daltonize
daltonize.simulate_mpl(fig, color_deficit='p')
